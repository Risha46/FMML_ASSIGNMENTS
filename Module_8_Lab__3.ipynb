# %% [markdown]
# <a href="https://colab.research.google.com/github/Risha46/FMML_ASSIGNMENTS/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 09:24:21--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  87.1MB/s    in 0.8s
#
# 2024-03-28 09:24:22 (87.1 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22435  1606.09066v3  Tree ensembles, such as random forests and boo...  stat
# 24087  1612.05234v1  We introduce the concept of a Visual Compiler ...    cs
# 21732   1406.0531v2  One of the most fundamental problems in causal...  stat
# 30389  1712.01111v1  In this paper, we propose an end-to-end 3D CNN...    cs
# 11935  1704.04050v1  Recently manifold learning algorithm for dimen...  stat
# ...             ...                                                ...   ...
# 7719   1802.10489v1  Suppose that we wish to estimate a vector $\ma...  stat
# 32282   1403.3465v3  We present tools for the analysis of Follow-Th...    cs
# 12141  1709.02726v1  Recently, much work has been done on extending...    cs
# 23021  1802.03759v1  There are a multitude of methods to perform mu...  stat
# 6728   1705.08665v4  Compression and computational efficiency in de...  stat
#
#                                                    title  year  \
# 22435  Making Tree Ensembles Interpretable: A Bayesia...  2016
# 24087  Visual Compiler: Synthesizing a Scene-Specific...  2016
# 21732  Causal Inference through a Witness Protection ...  2014
# 30389  An End-to-end 3D Convolutional Neural Network ...  2017
# 11935  Adaptive Neighboring Selection Algorithm Based...  2017
# ...                                                  ...   ...
# 7719   As you like it: Localization via paired compar...  2018
# 32282  A Survey of Algorithms and Analysis for Adapti...  2014
# 12141  A Modular Analysis of Adaptive (Non-)Convex Op...  2017
# 23021  Multi-set Canonical Correlation Analysis simpl...  2018
# 6728              Bayesian Compression for Deep Learning  2017
#
#                                                 keywords
# 22435  [ensembles, prediction, performance, interpret...
# 24087  [introduce, generates, pedestrian, estimator, ...
# 21732  [fundamental, inference, estimation, variables...
# 30389  [detection, segmentation, architecture, recogn...
# 11935  [algorithm, dimensionality, reduction, interes...
# ...                                                  ...
# 7719   [comparisons, estimating, observation, includi...
# 32282  [regularized, averaging, algorithms, regulariz...
# 12141  [extending, incremental, stochastic, optimizat...
# 23021  [multitude, correlated, component, including, ...
# 6728   [compression, computational, efficiency, signi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22435    [ensembles, prediction, performance, interpret...
# 24087    [introduce, generates, pedestrian, estimator, ...
# 21732    [fundamental, inference, estimation, variables...
# 30389    [detection, segmentation, architecture, recogn...
# 11935    [algorithm, dimensionality, reduction, interes...
#                                ...
# 37       [encountering, properties, deformability, inte...
# 25346    [technique, structural, constraints, computati...
# 32440    [clustering, technique, clustering, eigenprobl...
# 14227    [dimensional, strongest, relationships, depend...
# 6926     [simulators, increasingly, generative, paramet...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8750 words.
# Out of those 4572 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8dc097ba-d2a8-4428-ad24-d34beab62062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8dc097ba-d2a8-4428-ad24-d34beab62062")) {                    Plotly.newPlot(                        "8dc097ba-d2a8-4428-ad24-d34beab62062",                        [{"x":["prediction","ensembles","approximated","selection","simplifying","experiments","formalize","essentially","equivalent","complicated","performance","representation","maintaining","optimizes","specifically","critically","interpretable","interpretability","complexity","simplified","obtaining","algorithm","numerical","simplification","reasonably","segmentation","pedestrian","estimators","demonstrate","convolutional","outperforms","generation","introduce","auxiliary","bootstrapping","observations","spatially","annotated","geometrically","rendering","synthesizing","detection","experimental","generates","information","parameters","pedestrians","detectors","geometric","simultaneous","estimator","excellent","estimation","existence","conditional","posterior","inference","faithfulness","confounding","variables","confounded","difficult","protection","estimating","programming","condition","independencies","distribution","fundamental","observational","confounders","recognize","different","formulate","framework","regression","foreground","leveraging","performed","generated","convolution","segmented","proposals","architecture","structure","extensive","localization","explicitly","effectively","annotations","theoretical","quantitative","generally","neighbors","successfully","references","neighboring","nonlinear","increased","interests","simulation","relatively","dimensionality","embedding","mathematical","algorithms","verifying","reduction","visualization","curvature","comparison","significantly","attention","intermediate","classifiers","understanding","visualize","consequences","reputation","inception","discriminating","intuition","heuristics","classifier","potential","understand","recognition","structured","resulting","performing","graphical","heuristic","distributions","automatically","stochastic","approximation","factorization","sequential","approximations","procedure","independent","represents","particular","accelerate","constructing","techniques","impossible","coordinate","internally","achievable","carefully","appearance","disadvantage","furthermore","euclidean","constructed","approaches","measurements","distinguish","combination","arbitrary","mechanisms","similarity","computational","previously","observers","comparing","demonstrates","concretely","bipartite","conducted","projection","subnetworks","homogeneous","partition","clustering","heterogeneous","baselines","projective","extracted","relations","classification","concatenate","simultaneously","instability","statistical","properties","stability","developed","distorted","investigated","attentions","hierarchical","regularization","traditional","optimally","application","dimensional","effectiveness","criterion"],"y":[248,10,20,156,5,608,15,30,42,40,871,353,39,14,169,8,25,16,226,17,48,813,71,10,12,230,25,14,579,384,280,135,344,27,14,70,23,75,6,18,7,384,368,52,698,257,20,43,77,22,29,28,196,26,101,30,206,2,1,121,1,151,4,68,121,51,3,238,87,7,0,45,738,49,546,137,21,57,121,172,55,29,31,247,354,176,71,64,110,72,147,71,73,22,78,7,15,64,39,18,74,69,64,106,57,602,3,110,35,6,159,299,164,26,103,144,14,13,2,8,8,21,46,149,141,71,355,114,129,80,68,56,132,187,136,125,28,68,31,119,141,46,274,20,35,360,16,20,6,16,28,89,2,163,35,65,473,49,24,125,85,50,161,278,86,9,87,58,6,5,82,46,3,14,25,152,28,56,7,110,87,489,6,112,8,169,236,31,216,10,55,5,109,73,174,18,241,180,191,46],"type":"bar"},{"x":["prediction","ensembles","approximated","selection","simpli ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4572,), (4572, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7925

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Article</span> <span style=''>Ranking</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constrained</span> <span style=''>Dynamic</span> <span style=''>Multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>Problem</span> <br/><br/><span style=''>The</span> <span style=''>content</span> <span style=''>ranking</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>a</span> <span style=''>social</span> <span style=''>news</span> <span style=''>website</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>a</span> <span style=''>function</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizes</span> <span style=''>a</span> <span style=''>scalar</span> <span style=''>metric</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>like</span> <span style=''>dwell</span> <span style=''>time</span> <span style=''>However</span> <span style=''>like</span> <span style=''>in</span> <span style=''>most</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interested</span> <span style=''>in</span> <span style=''>more</span> <span style=''>than</span> <span style=''>one</span> <span style=''>metric</span> <span style=''>for</span> <span style=''>instance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>click</span> <span style=''>through</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>monetization</span> <span style=''>metrics</span> <span style=''>dwell</span> <span style=''>time</span> <span style=''>and</span> <span style=''>also</span> <span style=''>satisfy</span> <span style=''>the</span> <span style=''>traffic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirements</span> <span style=''>promised</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.312);'>different</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>publishers</span> <span style=''>All</span> <span style=''>this</span> <span style=''>needs</span> <span style=''>to</span> <span style=''>be</span> <span style=''>done</span> <span style=''>on</span> <span style=''>online</span> <span style=''>data</span> <span style=''>and</span> <span style=''>under</span> <span style=''>the</span> <span style=''>settings</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3499999999999999);'>dynamically</span> <span style=''>change</span> <span style=''>this</span> <span style=''>could</span> <span style=''>happen</span> <span style=''>if</span> <span style=''>for</span> <span style=''>instance</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>publishers</span> <span style=''>are</span> <span style=''>added</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>contracts</span> <span style=''>are</span> <span style=''>adjusted</span> <span style=''>or</span> <span style=''>if</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>contracts</span> <span style=''>are</span> <span style=''>over< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>outcome</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>forward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stagewise</span> <span style=''>approach</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>of</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>where</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinearly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>outcome</span> <span style=''>variable</span> <span style=''>The</span> <span style=''>method</span> <span style=''>doesnt</span> <span style=''>assume</span> <span style=''>any</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>and</span> <span style=''>can</span> <span style=''>select</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidates</span> <span style=''>It</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>forward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stagewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>in</span> <span style=''>which</span> <span style=''>very</span> <span style=''>small</span> <span style=''>steps</span> <span style=''>are</span> <span style=''>taken</span> <span style=''>to</span> <span style=''>select</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Given</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>we</span> <span style=''>devised</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>termed</span> <span style=''>roughening</span> <span style=''>to</span> <span style=''>adjust</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>residuals</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>we</span> <span style=''>show</span> <span style=''>the</span> <span style=''>new</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>against</span> <span style=''>popular</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Slice</span> <span style=''>Sampler</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Restricted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>Beta</span> <span style=''>Process</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style=''>Shared</span> <span style=''>Subspace</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>beta</span> <span style=''>process</span> <span style=''>has</span> <span style=''>found</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>modified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>beta</span> <span style=''>process</span> <span style=''>prior</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>modeling</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>data</span> <span style=''>sources</span> <span style=''>The</span> <span style=''>novel</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>prior</span> <span style=''>over</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>factor</span> <span style=''>model</span> <span style=''>allows</span> <span style=''>factors</span> <span style=''>to</span> <span style=''>be</span> <span style=''>shared</span> <span style=''>across</span> <span style='background-color:rgba(0, 255, 0, 0.312);'>different</span> <span style=''>sources</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>slice</span> <span style=''>sampler</span> <span style=''>for</span> <span style=''>this</span> <span style=''>model</span> <span style=''>enabling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style='background-color:rgba(255, 0, 0, 0.3408);'>inference</span> <span style=''>even</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4796747967479675);'>likelihood</span> <span style=''>and</span> <span style=''>the</span> <span style=''>prior</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.75);'>conjugate</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>in</span> <span style=''>much</span> <span style=''>wider</span> <span style=''>contexts</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.3793103448275861);'>restrictions</span> <span style=''>We</span> <span style=''>present</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.312);'>different</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>GaussianGaussian</span> <span style=''>model</span> <span style=''>for</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparsity</span> <span style=''>based</span> <span style=''>Defense</span> <span style=''>against</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Attacks</span> <span style=''>on</span> <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <br/><br/><span style=''>Deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>a</span> <span style=''>growing</span> <span style=''>number</span> <span style=''>of</span> <span style=''>fields</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>vision</span> <span style=''>speech</span> <span style=''>and</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>However</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>raises</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>by</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>induce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>errors</span> <span style=''>through</span> <span style=''>tiny</span> <span style=''>almost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imperceptible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Vulnerability</span> <span style=''>to</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>attacks</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjectured</span> <span style=''>to</span> <span style=''>be</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excessive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>linearity</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomenon</span> <span style=''>in</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>of</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>sparsity</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>data</span> <span style=''>to</span> <span style=''>combat</span> <span style=''>ell</span> <span style=''>infty</span> <span style=''>bounded</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12451499118165785)
# 	automatic (0.0673721340388007)
# 	knowledge (0.12134038800705467)
# 	information (0.24620811287477953)
# 	architecture (0.0871252204585538)
# 	segmentation (0.08112874779541446)
# 	different (0.26031746031746034)
# 	recognition (0.12522045855379188)
# 	detection (0.13544973544973546)
# 	convolutional (0.13544973544973546)
#
# Some Statistics words are:
# 	stochastic (0.13893129770992366)
# 	theoretical (0.15419847328244274)
# 	estimation (0.17150127226463105)
# 	variables (0.1465648854961832)
# 	statistical (0.1643765903307888)
# 	distribution (0.18982188295165395)
# 	algorithm (0.4040712468193384)
# 	regression (0.17760814249363868)
# 	dimensional (0.19592875318066158)
# 	inference (0.21323155216284986)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b66a15f9-9b1e-44ad-b4e3-f143d87e3efb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b66a15f9-9b1e-44ad-b4e3-f143d87e3efb")) {                    Plotly.newPlot(                        "b66a15f9-9b1e-44ad-b4e3-f143d87e3efb",                        [{"x":["prediction","ensembles","approximated","selection","simplifying","experiments","formalize","essentially","equivalent","complicated","performance","representation","maintaining","optimizes","specifically","critically","interpretable","interpretability","complexity","simplified","obtaining","algorithm","numerical","simplification","reasonably","segmentation","pedestrian","estimators","demonstrate","convolutional","outperforms","generation","introduce","auxiliary","bootstrapping","observations","spatially","annotated","geometrically","rendering","synthesizing","detection","experimental","generates","information","parameters","pedestrians","detectors","geometric","simultaneous","estimator","excellent","estimation","existence","conditional","posterior","inference","faithfulness","confounding","variables","confounded","difficult","protection","estimating","programming","condition","independencies","distribution","fundamental","observational","confounders","recognize","different","formulate","framework","regression","foreground","leveraging","performed","generated","convolution","segmented","proposals","architecture","structure","extensive","localization","explicitly","effectively","annotations","theoretical","quantitative","generally","neighbors","successfully","references","neighboring","nonlinear","increased","interests","simulation","relatively","dimensionality","embedding","mathematical","algorithms","verifying","reduction","visualization","curvature","comparison","significantly","attention","intermediate","classifiers","understanding","visualize","consequences","reputation","inception","discriminating","intuition","heuristics","classifier","potential","understand","recognition","structured","resulting","performing","graphical","heuristic","distributions","automatically","stochastic","approximation","factorization","sequential","approximations","procedure","independent","represents","particular","accelerate","constructing","techniques","impossible","coordinate","internally","achievable","carefully","appearance","disadvantage","furthermore","euclidean","constructed","approaches","measurements","distinguish","combination","arbitrary","mechanisms","similarity","computational","previously","observers","comparing","demonstrates","concretely","bipartite","conducted","projection","subnetworks","homogeneous","partition","clustering","heterogeneous","baselines","projective","extracted","relations","classification","concatenate","simultaneously","instability","statistical","properties","stability","developed","distorted","investigated","attentions","hierarchical","regularization","traditional","optimally","application","dimensional","effectiveness","criterion","uninformative","relaxation","addresses","nonconvex","important","predictors","supervised","configurations","generalization","scenarios","extrapolating","impressive","intelligently","unsupervised","predicting","generalizable","predictive","generalize","straggler","assumptions","gradients","stragglers","considers","convergence","asynchronous","adversely","exponential","synchronous","alleviate","analyzing","distributed","characterization","staleness","databases","individual","identification","robustness","evaluated","landmarks","paramount","technique","extraction","evaluation","partially","decoupling","importance","variability","connected","therefore","deformable","typically","semantically","ontologies","implement","extendin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounders
# 	uninformative
# 	extrapolating
# 	straggler
# 	stragglers
# 	unnormalized
# 	retention
# 	accounted
# 	stationarities
# 	semiparametric
# 	microphone
# 	identifiability
# 	nonstandard
# 	parallelizes
# 	criticized
# 	hermitian
# 	approachability
# 	blackwells
# 	blockmodels
# 	blockmodel
# Some words which never appear in Statistics papers:
# 	pedestrian
# 	disadvantage
# 	observers
# 	subnetworks
# 	interdependencies
# 	intelligible
# 	misspelled
# 	confusing
# 	exposures
# 	sharpening
# 	consolidate
# 	argumentation
# 	prisoners
# 	defection
# 	illumination
# 	backtrack
# 	colorization
# 	objection
# 	objections
# 	abstractive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0374825344754272e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7316666666666667
